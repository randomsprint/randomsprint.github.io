# %% [markdown]
# # Random Sprint
#
# This is an attempt to make a website (mostly) in iPython notebooks. It will serve as a portfolio for my projects.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Let's see what Jekyll does to the formatting.

# %%
welcome_string = 'Hello World'
welcome_string = welcome_string.upper()
print(welcome_string)

for idx, letter in enumerate(welcome_string):
    if idx == 0:
        continue
    print(letter)
# Out:
# HELLO WORLD
# E
# L
# L
# O
#
# W
# O
# R
# L
# D
